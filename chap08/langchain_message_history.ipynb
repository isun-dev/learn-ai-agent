# %%
import os
os.environ['OPENAI_API_KEY'] = ''

from langchain_core.chat_history import InMemoryChatMessageHistory  # 메모리에 대화 기록을 저장하는 클래스
from langchain_core.runnables.history import RunnableWithMessageHistory  # 메시지 기록을 활용해 실행 가능한 래퍼wrapper 클래스
from langchain_openai import ChatOpenAI  # 오픈AI 모델을 사용하는 랭체인 챗봇 클래스
from langchain_core.messages import HumanMessage

model = ChatOpenAI(model="gpt-4o-mini")
# 세션별 대화 기록을 저장할 딕셔너리
store = {}

# 세션 ID에 따라 대화 기록을 가져오는 함수
def get_session_history(session_id: str):
    # 만약 해당 세션 ID가 store에 없으면, 새로 생성해 추가함
    if session_id not in store:
        store[session_id] = InMemoryChatMessageHistory()  # 메모리에 대화 기록을 저장하는 객체 생성
    return store[session_id]  # 해당 세션의 대화 기록을 반환

# 모델 실행 시 대화 기록을 함께 전달하는 래퍼 객체 생성
with_message_history = RunnableWithMessageHistory(model, get_session_history)
# Out:
# /Users/nicole/Documents/CodexProjects/learn-ai-agent/.venv/lib/python3.12/site-packages/IPython/core/interactiveshell.py:3748: LangChainDeprecationWarning: RunnableWithMessageHistory is deprecated. Use LangGraph's built-in persistence instead.
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
config = {"configurable": {"session_id": "abc2"}}  # 세션 ID를 설정하는 config 객체 생성

response = with_message_history.invoke(
    [HumanMessage(content="안녕? 난 이성용이야.")],
    config=config,
)

print(response.content)
# Out:
# 안녕하세요, 이성용님! 만나서 반갑습니다. 어떻게 도와드릴까요?

# %%
response = with_message_history.invoke(
    [HumanMessage(content="내 이름이 뭐지?")],
    config=config,
)

print(response.content)
# Out:
# 당신의 이름은 이성용입니다. 맞나요?

# %%
config = {"configurable": {"session_id": "abc3"}}

response = with_message_history.invoke(
    [HumanMessage(content="내 이름이 뭐지?")],
    config=config,
)

response.content
# Out:
# '죄송하지만, 당신의 이름을 알 수 있는 정보는 없습니다. 하지만 궁금한 점이나 도움이 필요하신 다른 내용이 있으면 말씀해 주세요!'

# %%
config = {"configurable": {"session_id": "abc2"}}

response = with_message_history.invoke(
    [HumanMessage(content="아까 우리가 무슨 얘기 했지?")],
    config=config,
)

response.content
# Out:
# '앞서서 당신의 이름이 이성용이라고 말씀하셨습니다. 그 외에 특별한 이야기는 나눈 게 없습니다. 어떤 이야기를 나누고 싶으신가요?'

# %%
config = {"configurable": {"session_id": "abc2"}}
for r in with_message_history.stream(
    [HumanMessage(content = "내가 어느 나라 사람인지 맞춰보고, 그 나라의 문화에 대해 말해봐")],
    config=config,
):
    print(r.content, end="|")
# Out:
# |제가| 직접| 사람|을| 맞|출| 수|는| 없|지만|,| 이름|에서| 유|추|해|보|면| 한국|어| 이름|인| 이|성|용|은| 한국|에서| 흔|히| 사용|되는| 이름| 중| 하나|입니다|.| 만|약| 한국| 사람|이라|면|,| 한국|의| 문화|에| 대해| 몇| 가지| 말씀|드|릴| 수| 있습니다|.
#
# |한국|은| 매우| 풍|부|한| 전|통|과| 현대| 문화|가| 공|존|하는| 나라|입니다|.|
#
# |1|.| **|음|식|**|:| 한국|은| 다양한| 전|통| 음식|이| 있으며|,| 김|치|,| 비|빔|밥|,| 불|고|기|와| 같은| 요|리가| 유명|합니다|.| 한국|의| BBQ|는| 특히| 인|기가| 많|습니다|.
#
# |2|.| **|예|절|**|:| 한국|은| 예|의|와| 존|중|을| 중요|시|합니다|.| 인|사|할| 때| 고|개|를| 숙|이는| 것이| 일반|적|이며|,| 나|이에| 따라| 존|댓|말|을| 사용하는| 문화|가| 있습니다|.
#
# |3|.| **|명|절|**|:| 설|날|(|구|정|)|과| 추|석|(|한|가|위|)| 같은| 전|통| 명|절|은| 가족|이| 모|여|서| 차|례|를| 지|내|고| 음|식을| 나|누|는| 중요한| 행사|입니다|.
#
# |4|.| **|한|복|**|:| 전|통| 의|상|인| 한|복|은| 특별|한| 날|에| 주|로| 착|용|하며|,| 색|상|과| 디자인|이| 다양|합니다|.|
#
# |5|.| **|K|-pop|과| 한|류|**|:| 최근| 몇| 년|간| K|-pop|과| 한국| 드|라마|가| 국제|적으로| 큰| 인|기를| 끌|고| 있습니다|.| BTS|와| 블|랙|핑|크| 같은| 그룹|은| 전| 세계|적으로| 많은| 팬|을| 보|유|하고| 있습니다|.
#
# |혹|시| 한국|이| 맞|나요|?| 또는| 다른| 나라|에| 대해서| 궁|금|한| 점|이| 있으|신|가|요|?||||
